# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True)

# %%
# Confirm folder was created and files added successfully
os.listdir("Data/")
# Out:
# ['.ipynb_checkpoints',
#  'basics-data.tsv',
#  'basics.csv',
#  'ratings-data.tsv',
#  'title-akas-us-only.csv']

# %%
# Load importsa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Load basics
basics = pd.read_csv("Data/basics-data.tsv", sep='\t', low_memory = False)
basics
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10017006  tt9916848  tvEpisode              Episode #3.17
# 10017007  tt9916850  tvEpisode              Episode #3.19
# 10017008  tt9916852  tvEpisode              Episode #3.20
# 10017009  tt9916856      short                   The Wind
# 10017010  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# 2                    Pauvre Pierrot       0      1892      \N              4
# 3                       Un bon bock       0      1892      \N             12
# 4                  Blacksmith Scene       0      1893      \N              1
# ...                             ...     ...       ...     ...            ...
# 10017006              Episode #3.17       0      2009      \N             \N
# 10017007              Episode #3.19       0      2010      \N             \N
# 10017008              Episode #3.20       0      2010      \N             \N
# 10017009                   The Wind       0      2015      \N             27
# 10017010  Horrid Henry Knows It All       0      2014      \N             10
#
#                               genres
# 0                  Documentary,Short
# 1                    Animation,Short
# 2           Animation,Comedy,Romance
# 3                    Animation,Short
# 4                       Comedy,Short
# ...                              ...
# 10017006         Action,Drama,Family
# 10017007         Action,Drama,Family
# 10017008         Action,Drama,Family
# 10017009                       Short
# 10017010  Adventure,Animation,Comedy
#
# [10017011 rows x 9 columns]

# %%
# Load akas
akas = pd.read_csv('Data/title-akas-us-only.csv')
akas
# Out:
# C:\Users\JOSH\AppData\Local\Temp\ipykernel_16220\4156617921.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   akas = pd.read_csv('Data/title-akas-us-only.csv')
#            titleId  ordering                                      title  \
# 0        tt0000001         6                                 Carmencita
# 1        tt0000002         7                     The Clown and His Dogs
# 2        tt0000005        10                           Blacksmith Scene
# 3        tt0000005         1                        Blacksmithing Scene
# 4        tt0000005         6                        Blacksmith Scene #1
# ...            ...       ...                                        ...
# 1452559  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 1452560  tt9916620         1                          The Copeland Case
# 1452561  tt9916702         1              Loving London: The Playground
# 1452562  tt9916756         1                   Pretty Pretty Black Girl
# 1452563  tt9916764         1                                         38
#
#         region language        types             attributes isOriginalTitle
# 0           US       \N  imdbDisplay                     \N               0
# 1           US       \N           \N  literal English title               0
# 2           US       \N  imdbDisplay                     \N               0
# 3           US       \N  alternative                     \N               0
# 4           US       \N  alternative                     \N               0
# ...        ...      ...          ...                    ...             ...
# 1452559     US       \N  imdbDisplay                     \N               0
# 1452560     US       \N  imdbDisplay                     \N               0
# 1452561     US       \N           \N                     \N               0
# 1452562     US       \N  imdbDisplay                     \N               0
# 1452563     US       \N  imdbDisplay                     \N               0
#
# [1452564 rows x 8 columns]

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
filter_us_titles = basics['tconst'].isin(akas['titleId'])
basics = basics[filter_us_titles]
basics
# Out:
#              tconst titleType                                 primaryTitle  \
# 0         tt0000001     short                                   Carmencita
# 1         tt0000002     short                       Le clown et ses chiens
# 4         tt0000005     short                             Blacksmith Scene
# 5         tt0000006     short                            Chinese Opium Den
# 6         tt0000007     short  Corbett and Courtney Before the Kinetograph
# ...             ...       ...                                          ...
# 10016872  tt9916560   tvMovie    March of Dimes Presents: Once Upon a Dime
# 10016901  tt9916620     movie                            The Copeland Case
# 10016939  tt9916702     short                Loving London: The Playground
# 10016962  tt9916756     short                     Pretty Pretty Black Girl
# 10016966  tt9916764     short                                           38
#
#                                         originalTitle isAdult startYear  \
# 0                                          Carmencita       0      1894
# 1                              Le clown et ses chiens       0      1892
# 4                                    Blacksmith Scene       0      1893
# 5                                   Chinese Opium Den       0      1894
# 6         Corbett and Courtney Before the Kinetograph       0      1894
# ...                                               ...     ...       ...
# 10016872    March of Dimes Presents: Once Upon a Dime       0      1963
# 10016901                            The Copeland Case       0        \N
# 10016939                Loving London: The Playground       0        \N
# 10016962                     Pretty Pretty Black Girl       0      2019
# 10016966                                           38       0      2018
#
#          endYear runtimeMinutes             genres
# 0             \N              1  Documentary,Short
# 1             \N              5    Animation,Short
# 4             \N              1       Comedy,Short
# 5             \N              1              Short
# 6             \N              1        Short,Sport
# ...          ...            ...                ...
# 10016872      \N             58             Family
# 10016901      \N             \N              Drama
# 10016939      \N             \N        Drama,Short
# 10016962      \N             \N              Short
# 10016966      \N             \N              Short
#
# [1365643 rows x 9 columns]

# %%
# Replace '\N' to 'nan' in basics
basics = basics.replace({'\\N':np.nan})

# %%
# Check nulls in 'runtimeMinutes'
basics['runtimeMinutes'].isna().sum()
# Out:
# 503119

# %%
# Drop rows with nulls on 'runtimeMinutes'
basics.dropna(subset = ['runtimeMinutes'], inplace = True)

# %%
# Check nulls in 'runtimeMinutes'
basics['runtimeMinutes'].isna().sum()
# Out:
# 0

# %%
# Filter to keep only full-length movies (titleType == Movie)
basics = basics.loc[basics['titleType'] == 'movie']

# %%
# Convert startYear to a float dtype 
basics['startYear'] = basics['startYear'].astype(float)

# %%
# Filter to keep movies with startYear that are >= 2000 and <= 2022
basics = basics.loc[(basics['startYear'] >= 2000) & (basics['startYear'] <= 2022)]
basics
# Out:
#              tconst titleType  \
# 34802     tt0035423     movie
# 61114     tt0062336     movie
# 67666     tt0069049     movie
# 86793     tt0088751     movie
# 93930     tt0096056     movie
# ...             ...       ...
# 10016366  tt9915436     movie
# 10016544  tt9915872     movie
# 10016684  tt9916170     movie
# 10016693  tt9916190     movie
# 10016777  tt9916362     movie
#
#                                                primaryTitle  \
# 34802                                        Kate & Leopold
# 61114     The Tango of the Widower and Its Distorting Mi...
# 67666                            The Other Side of the Wind
# 86793                                     The Naked Monster
# 93930                                  Crime and Punishment
# ...                                                     ...
# 10016366                                  Vida em Movimento
# 10016544                               The Last White Witch
# 10016684                                      The Rehearsal
# 10016693                                          Safeguard
# 10016777                                              Coven
#
#                                       originalTitle isAdult  startYear  \
# 34802                                Kate & Leopold       0     2001.0
# 61114     El tango del viudo y su espejo deformante       0     2020.0
# 67666                    The Other Side of the Wind       0     2018.0
# 86793                             The Naked Monster       0     2005.0
# 93930                          Crime and Punishment       0     2002.0
# ...                                             ...     ...        ...
# 10016366                          Vida em Movimento       0     2019.0
# 10016544                  My Girlfriend is a Wizard       0     2019.0
# 10016684                                   O Ensaio       0     2019.0
# 10016693                                  Safeguard       0     2020.0
# 10016777                                   Akelarre       0     2020.0
#
#          endYear runtimeMinutes                     genres
# 34802        NaN            118     Comedy,Fantasy,Romance
# 61114        NaN             70                      Drama
# 67666        NaN            122                      Drama
# 86793        NaN            100       Comedy,Horror,Sci-Fi
# 93930        NaN            126                      Drama
# ...          ...            ...                        ...
# 10016366     NaN             70                Documentary
# 10016544     NaN             97       Comedy,Drama,Fantasy
# 10016684     NaN             51                      Drama
# 10016693     NaN             95  Action,Adventure,Thriller
# 10016777     NaN             92              Drama,History
#
# [122694 rows x 9 columns]

# %%
# Eliminate movies that include 'Documentary' in genre 
filter_documentaries = basics['genres'].str.contains('Documentary', na = False)

# Exclude movies that include 'Documentary' in genre
basics = basics[~filter_documentaries]

# %%
# Display a final preview of your filtered title basiscs and save to a csv 
basics.info()
basics.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88546 entries, 34802 to 10016777
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          88546 non-null  object
#  1   titleType       88546 non-null  object
#  2   primaryTitle    88546 non-null  object
#  3   originalTitle   88546 non-null  object
#  4   isAdult         88546 non-null  object
#  5   startYear       88546 non-null  float64
#  6   endYear         0 non-null      object
#  7   runtimeMinutes  88546 non-null  object
#  8   genres          86979 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 6.8+ MB
#            tconst titleType  \
# 34802   tt0035423     movie
# 61114   tt0062336     movie
# 67666   tt0069049     movie
# 86793   tt0088751     movie
# 93930   tt0096056     movie
# 98035   tt0100275     movie
# 101033  tt0103340     movie
# 106097  tt0108549     movie
# 110468  tt0113026     movie
# 110531  tt0113092     movie
#
#                                              primaryTitle  \
# 34802                                      Kate & Leopold
# 61114   The Tango of the Widower and Its Distorting Mi...
# 67666                          The Other Side of the Wind
# 86793                                   The Naked Monster
# 93930                                Crime and Punishment
# 98035                            The Wandering Soap Opera
# 101033                    Life for Life: Maximilian Kolbe
# 106097                         West from North Goes South
# 110468                                    The Fantasticks
# 110531                                      For the Cause
#
#                                     originalTitle isAdult  startYear endYear  \
# 34802                              Kate & Leopold       0     2001.0     NaN
# 61114   El tango del viudo y su espejo deformante       0     2020.0     NaN
# 67666                  The Other Side of the Wind       0     2018.0     NaN
# 86793                           The Naked Monster       0     2005.0     NaN
# 93930                        Crime and Punishment       0     2002.0     NaN
# 98035                       La Telenovela Errante       0     2017.0     NaN
# 101033          Zycie za zycie. Maksymilian Kolbe       0     2006.0     NaN
# 106097                 West from North Goes South       0     2004.0     NaN
# 110468                            The Fantasticks       0     2000.0     NaN
# 110531                              For the Cause       0     2000.0     NaN
#
#        runtimeMinutes                  genres
# 34802             118  Comedy,Fantasy,Romance
# 61114              70                   Drama
# 67666             122                   Drama
# 86793             100    Comedy,Horror,Sci-Fi
# 93930             126                   Drama
# 98035              80    Comedy,Drama,Fantasy
# 101033             90         Biography,Drama
# 106097             96          Comedy,Mystery
# 110468             86         Musical,Romance
# 110531            100  Action,Adventure,Drama

# %%
# Save the basics data to a CSV file in Data folder
#basics.to_csv('D:\My Documents\GitHub\Project-2')

# %%
# Load the title rating data into a dataframe
ratings = pd.read_csv('Data/ratings-data.tsv', sep='\t')
ratings.info()
ratings.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1331492 entries, 0 to 1331491
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1331492 non-null  object
#  1   averageRating  1331492 non-null  float64
#  2   numVotes       1331492 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 30.5+ MB
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1988
# 1  tt0000002            5.8       265
# 2  tt0000003            6.5      1849
# 3  tt0000004            5.5       178
# 4  tt0000005            6.2      2632

# %%
# Keep only movies that are included in final title basics dataframe 
filter_basics = ratings['tconst'].isin(basics['tconst'])
ratings = ratings.loc[filter_basics]

# %%
# Final preview of ratings dataframe 
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72482 entries, 17961 to 1331462
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         72482 non-null  object
#  1   averageRating  72482 non-null  float64
#  2   numVotes       72482 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
# Save the ratings data to a CSV file in Data folder
#ratings.to_csv('D:\\My Documents\\GitHub\\Project-2\\Data\\ratings.csv')
